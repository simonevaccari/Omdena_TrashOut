# %% [markdown]
# # **Omdena TrashOut - Task1.1 Cities and Population**
#
# *by Simone Vaccari*

# %%
import geemap
import pandas as pd
import os

# %%
m = geemap.Map()
m
# Out:
# Map(center=[40, -100], controls=(WidgetControl(options=['position'], widget=HBox(children=(ToggleButton(value=…

# %%
fname = 'pop_den_2020_5km.tif'

# %%
mydir = os.path.join(os.path.expanduser('~'),'Downloads', 'Omdena', 'pop_den_2020_5km'); #print(os.listdir(mydir))
popden_rst = os.path.join(mydir, fname); assert(os.path.isfile(popden_rst))

# %%
Map = geemap.Map()

# %%
Map.add_raster(popden_rst, layer_name='Population Density 2020')
# Out:
# You need to install xarray_leaflet first. See https://github.com/davidbrochart/xarray_leaflet
# Try the following to install xarray_leaflet:
#
# conda install -c conda-forge xarray_leaflet
