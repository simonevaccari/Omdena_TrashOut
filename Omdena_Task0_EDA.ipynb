# %% [markdown]
# # **Omdena TrashOut - Task0 Explanatory Data Analysis (EDA)**
#
# *by Simone Vaccari*

# %% [markdown]
# # Set-up

# %% [markdown]
# ## Google Drive

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# ## Change Working Directory

# %%
cd /content/drive/My Drive/Omdena
# Out:
# /content/drive/My Drive/Omdena

# %% [markdown]
# # Read CSVs Data

# %%
import pandas as pd
import os

# %%
# !pip install geopandas
# Out:
# Collecting geopandas
#   Downloading https://files.pythonhosted.org/packages/f8/dd/c0a6429cc7692efd5c99420c9df525c40f472b50705871a770449027e244/geopandas-0.8.0-py2.py3-none-any.whl (962kB)
#      |████████████████████████████████| 962kB 2.5MB/s
# Requirement already satisfied: pandas>=0.23.0 in /usr/local/lib/python3.6/dist-packages (from geopandas) (1.0.5)
# Collecting fiona
#   Downloading https://files.pythonhosted.org/packages/ec/20/4e63bc5c6e62df889297b382c3ccd4a7a488b00946aaaf81a118158c6f09/Fiona-1.8.13.post1-cp36-cp36m-manylinux1_x86_64.whl (14.7MB)
#      |████████████████████████████████| 14.7MB 295kB/s
# Requirement already satisfied: shapely in /usr/local/lib/python3.6/dist-packages (from geopandas) (1.7.0)
# Collecting pyproj>=2.2.0
#   Downloading https://files.pythonhosted.org/packages/e5/c3/071e080230ac4b6c64f1a2e2f9161c9737a2bc7b683d2c90b024825000c0/pyproj-2.6.1.post1-cp36-cp36m-manylinux2010_x86_64.whl (10.9MB)
#      |████████████████████████████████| 10.9MB 40.4MB/s
# Requirement already satisfied: numpy>=1.13.3 in /usr/local/lib/python3.6/dist-packages (from pandas>=0.23.0->geopandas) (1.18.5)
# Requirement already satisfied: pytz>=2017.2 in /usr/local/lib/python3.6/dist-packages (from pandas>=0.23.0->geopandas) (2018.9)
# Requirement already satisfied: python-dateutil>=2.6.1 in /usr/local/lib/python3.6/dist-packages (from pandas>=0.23.0->geopandas) (2.8.1)
# Requirement already satisfied: click<8,>=4.0 in /usr/local/lib/python3.6/dist-packages (from fiona->geopandas) (7.1.2)
# Collecting click-plugins>=1.0
#   Downloading https://files.pythonhosted.org/packages/e9/da/824b92d9942f4e472702488857914bdd50f73021efea15b4cad9aca8ecef/click_plugins-1.1.1-py2.py3-none-any.whl
# Requirement already satisfied: six>=1.7 in /usr/local/lib/python3.6/dist-packages (from fiona->geopandas) (1.12.0)
# Collecting cligj>=0.5
#   Downloading https://files.pythonhosted.org/packages/e4/be/30a58b4b0733850280d01f8bd132591b4668ed5c7046761098d665ac2174/cligj-0.5.0-py3-none-any.whl
# Requirement already satisfied: attrs>=17 in /usr/local/lib/python3.6/dist-packages (from fiona->geopandas) (19.3.0)
# Collecting munch
#   Downloading https://files.pythonhosted.org/packages/cc/ab/85d8da5c9a45e072301beb37ad7f833cd344e04c817d97e0cc75681d248f/munch-2.5.0-py2.py3-none-any.whl
# Installing collected packages: click-plugins, cligj, munch, fiona, pyproj, geopandas
# Successfully installed click-plugins-1.1.1 cligj-0.5.0 fiona-1.8.13.post1 geopandas-0.8.0 munch-2.5.0 pyproj-2.6.1.post1

# %% [markdown]
# ### Read CSVs ALL AT ONCE
# All the csv files are in the "/content/drive/My Drive/Omdena/Data" folder

# %%
from shapely.geometry import Point
import geopandas as gpd
from geopandas import GeoDataFrame

# NB the following does NOT contain europe_1 and europe_8 for the problems outlined already. If someone has a working solution or has manually corrected the two CSV files, please share
continents = ['africa_0.csv', 'africa_1.csv', 'asia_0.csv', 'southamerica_0.csv', 'northamerica_0.csv', 'northamerica_1.csv', 'oceania_0.csv', 'australia_0.csv',
              'europe_0.csv', 'europe_2.csv', 'europe_3.csv', 'europe_4.csv', 'europe_5.csv', 'europe_6.csv', 'europe_7.csv']
#              'europe_0.csv', 'europe_1.csv', 'europe_2.csv', 'europe_3.csv', 'europe_4.csv', 'europe_5.csv', 'europe_6.csv', 'europe_7.csv', 'europe_8.csv']

world_combined = pd.concat([pd.read_csv('Data/'+f, error_bad_lines=False, sep=';') for f in continents])
print(world_combined.dtypes)

geometry = [Point(xy) for xy in zip(world_combined['longitude'], world_combined['latitude'])]
print(geometry)

print(world_combined.shape)
world_combined.head()
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %% [markdown]
# ### Read CSVs per Region

# %% [markdown]
# All the csv files are in the "/content/drive/My Drive/Omdena/Data" folder

# %%
africa = ['africa_0.csv', 'africa_1.csv']

africa_combined = pd.concat([pd.read_csv('Data/'+f, error_bad_lines=False, sep=';') for f in africa])

print(africa)
print(africa_combined.shape)
africa_combined.head()
# Out:
# ['africa_0.csv', 'africa_1.csv']
# (5324, 21)
#       id  ...                                              image
# 0  57838  ...  https://firebasestorage.googleapis.com/v0/b/tr...
# 1  57837  ...  https://firebasestorage.googleapis.com/v0/b/tr...
# 2  57836  ...  https://firebasestorage.googleapis.com/v0/b/tr...
# 3  57831  ...  https://firebasestorage.googleapis.com/v0/b/tr...
# 4  57830  ...  https://firebasestorage.googleapis.com/v0/b/tr...
#
# [5 rows x 21 columns]

# %%
asia = ['asia_0.csv']

asia_combined = pd.concat([pd.read_csv('Data/'+f, error_bad_lines=False, sep=';') for f in asia])

print(asia)
print(asia_combined.shape)
asia_combined.head()
# Out:
# ['asia_0.csv']
# (1512, 21)
#       id  ...                                              image
# 0  57823  ...  https://firebasestorage.googleapis.com/v0/b/tr...
# 1  57814  ...  https://firebasestorage.googleapis.com/v0/b/tr...
# 2  57758  ...  https://firebasestorage.googleapis.com/v0/b/tr...
# 3  57594  ...  https://firebasestorage.googleapis.com/v0/b/tr...
# 4  57585  ...  https://firebasestorage.googleapis.com/v0/b/tr...
#
# [5 rows x 21 columns]

# %%
samerica = ['southamerica_0.csv']
samerica_combined = pd.concat([pd.read_csv('Data/'+f, error_bad_lines=False, sep=';') for f in samerica])

print(samerica)
print(samerica_combined.shape)
samerica_combined.head()
# Out:
# ['southamerica_0.csv']
# (271, 21)
#       id  ...                                              image
# 0  57833  ...  https://firebasestorage.googleapis.com/v0/b/tr...
# 1  57799  ...  https://firebasestorage.googleapis.com/v0/b/tr...
# 2  57798  ...  https://firebasestorage.googleapis.com/v0/b/tr...
# 3  57797  ...  https://firebasestorage.googleapis.com/v0/b/tr...
# 4  57795  ...  https://firebasestorage.googleapis.com/v0/b/tr...
#
# [5 rows x 21 columns]

# %%
namerica = ['northamerica_0.csv', 'northamerica_1.csv']
namerica_combined = pd.concat([pd.read_csv('Data/'+f, error_bad_lines=False, sep=';') for f in namerica])

print(namerica)
print(namerica_combined.shape)
namerica_combined.head()
# Out:
# ['northamerica_0.csv', 'northamerica_1.csv']
# (6357, 21)
#       id  ...                                              image
# 0  57821  ...  https://firebasestorage.googleapis.com/v0/b/tr...
# 1  57802  ...  https://firebasestorage.googleapis.com/v0/b/tr...
# 2  57768  ...  https://firebasestorage.googleapis.com/v0/b/tr...
# 3  57757  ...  https://firebasestorage.googleapis.com/v0/b/tr...
# 4  57707  ...  https://firebasestorage.googleapis.com/v0/b/tr...
#
# [5 rows x 21 columns]

# %%
oceania = ['oceania_0.csv']
oceania_combined = pd.concat([pd.read_csv('Data/'+f, error_bad_lines=False, sep=';') for f in oceania])

print(oceania)
print(oceania_combined.shape)
oceania_combined.head()
# Out:
# ['oceania_0.csv']
# (11, 21)
#       id  ...                                              image
# 0  37325  ...  https://storage.googleapis.com/trashoutngo-dev...
# 1  36250  ...  https://storage.googleapis.com/trashoutngo-dev...
# 2  36168  ...  https://storage.googleapis.com/trashoutngo-dev...
# 3  35225  ...  https://storage.googleapis.com/trashoutngo-dev...
# 4  31723  ...  https://storage.googleapis.com/trashoutngo-dev...
#
# [5 rows x 21 columns]

# %%
australia = ['australia_0.csv']
australia_combined = pd.concat([pd.read_csv('Data/'+f, error_bad_lines=False, sep=';') for f in australia])

print(australia)
print(australia_combined.shape)
australia_combined.head()
# Out:
# ['australia_0.csv']
# (87, 21)
#       id  ...                                              image
# 0  57800  ...  https://firebasestorage.googleapis.com/v0/b/tr...
# 1  47318  ...  https://firebasestorage.googleapis.com/v0/b/tr...
# 2  45738  ...  https://firebasestorage.googleapis.com/v0/b/tr...
# 3  43336  ...  https://firebasestorage.googleapis.com/v0/b/tr...
# 4  42369  ...  https://storage.googleapis.com/trashoutngo-dev...
#
# [5 rows x 21 columns]

# %%
# I'm not using europe_1 nor europe_8 as they seem to have some problems with their data (needs solving...)

#europe = ['europe_0.csv', 'europe_1.csv', 'europe_2.csv', 'europe_3.csv', 
#          'europe_4.csv', 'europe_5.csv', 'europe_6.csv', 'europe_7.csv', 'europe_8.csv']
europe = ['europe_0.csv', 'europe_2.csv', 'europe_3.csv', 
          'europe_4.csv', 'europe_5.csv', 'europe_6.csv', 'europe_7.csv']

europe_combined = pd.concat([pd.read_csv('Data/'+f, error_bad_lines=False, sep=';') for f in europe])
print(europe_combined.dtypes)

#geometry = [Point(xy) for xy in zip(europe_combined['longitude'], europe_combined['latitude'])]
#print(geometry)

print(europe_combined)
print(europe_combined.shape)
europe_combined.head()
# Out:
# id                 int64
# latitude         float64
# longitude        float64
# continent         object
# country           object
# aa1               object
# aa2               object
# aa3               object
# locality          object
# subLocality       object
# types             object
# updateTime        object
# updateNeeded        bool
# note              object
# url               object
# status            object
# size              object
# anonymous           bool
# created           object
# accessibility     object
# image             object
# dtype: object
#          id  ...                                              image
# 0     57835  ...  https://firebasestorage.googleapis.com/v0/b/tr...
# 1     57834  ...  https://firebasestorage.googleapis.com/v0/b/tr...
# 2     57832  ...  https://firebasestorage.googleapis.com/v0/b/tr...
# 3     57827  ...  https://firebasestorage.googleapis.com/v0/b/tr...
# 4     57824  ...  https://firebasestorage.googleapis.com/v0/b/tr...
# ...     ...  ...                                                ...
# 4995   2931  ...  https://storage.googleapis.com/trashoutngo-dev...
# 4996   2930  ...  https://storage.googleapis.com/trashoutngo-dev...
# 4997   2929  ...  https://storage.googleapis.com/trashoutngo-dev...
# 4998   2928  ...  https://storage.googleapis.com/trashoutngo-dev...
# 4999   2927  ...  https://storage.googleapis.com/trashoutngo-dev...
#
# [35000 rows x 21 columns]
# (35000, 21)
#       id  ...                                              image
# 0  57835  ...  https://firebasestorage.googleapis.com/v0/b/tr...
# 1  57834  ...  https://firebasestorage.googleapis.com/v0/b/tr...
# 2  57832  ...  https://firebasestorage.googleapis.com/v0/b/tr...
# 3  57827  ...  https://firebasestorage.googleapis.com/v0/b/tr...
# 4  57824  ...  https://firebasestorage.googleapis.com/v0/b/tr...
#
# [5 rows x 21 columns]

# %% [markdown]
# #### Europe 1 & 8 problem
# there are some lines that have been misplaced from previous row(s) and therefore have wrong values across each field (error as string "stillHere" in Lat values). These lines start ";http..."

# %%
europe_combined[europe_combined['latitude']=='stillHere']
# Out:
#                                                      id  ... image
# 323   ;https://admin.trashout.ngo/trash-management/d...  ...   NaN
# 581   ;https://admin.trashout.ngo/trash-management/d...  ...   NaN
# 2072  ;https://admin.trashout.ngo/trash-management/d...  ...   NaN
#
# [3 rows x 21 columns]

# %%
# Convert the lat and long values to float (SOME(!) of them are string)
europe_combined['latitude'] = [float(lat) for lat in europe_combined['latitude']]

europe_combined['latitude'] = europe_combined['latitude'].apply(lambda x : x.replace("'",""))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-96-042e4a5af559> in <module>()
#       1 # Convert the lat and long values to float (SOME(!) of them are string)
# ----> 2 europe_combined['latitude'] = [float(lat) for lat in europe_combined['latitude']]
#       3
#       4 europe_combined['latitude'] = europe_combined['latitude'].apply(lambda x : x.replace("'",""))
#
# <ipython-input-96-042e4a5af559> in <listcomp>(.0)
#       1 # Convert the lat and long values to float (SOME(!) of them are string)
# ----> 2 europe_combined['latitude'] = [float(lat) for lat in europe_combined['latitude']]
#       3
#       4 europe_combined['latitude'] = europe_combined['latitude'].apply(lambda x : x.replace("'",""))
#
# ValueError: could not convert string to float: 'stillHere'

# %%
# this is to convert from string to float, but I dont think that the problem is only that. But rather the misalignment of some fields as described above
for xy in zip(europe_combined['longitude'], europe_combined['latitude']):
  print(xy, float(xy[0]), float(xy[1]))
# Out:
# Streaming output truncated to the last 5000 lines.
# (17.7498898097, 48.8331594877) 17.7498898097 48.8331594877
# (19.64714518, 40.86896663) 19.64714518 40.86896663
# (20.60618124, 41.065607899999996) 20.60618124 41.065607899999996
# (-5.84815979, 43.619052169899994) -5.84815979 43.619052169899994
# (21.2591330304, 42.3482401171) 21.2591330304 42.3482401171
# (17.0749453548, 48.1375946291) 17.0749453548 48.1375946291
# (20.291653221700003, 42.65565996) 20.291653221700003 42.65565996
# (17.01470893, 48.19844534) 17.01470893 48.19844534
# (19.6256321669, 49.086774587600004) 19.6256321669 49.086774587600004
# (38.3170383333, 55.21889) 38.3170383333 55.21889
# (18.08998085, 48.30968553) 18.08998085 48.30968553
# (15.062640733888859, 50.93347520992364) 15.062640733888859 50.93347520992364
# (17.94773499, 49.388283) 17.94773499 49.388283
# (18.8740932941, 49.17114079) 18.8740932941 49.17114079
# (37.5368317869, 55.709661366499994) 37.5368317869 55.709661366499994
# (21.29457009, 48.77543461) 21.29457009 48.77543461
# (20.2781806912, 42.6576078518) 20.2781806912 42.6576078518
# (21.2533983573, 42.2453871675) 21.2533983573 42.2453871675
# (21.370663003900003, 42.3944717811) 21.370663003900003 42.3944717811
# (21.297397337, 42.2986072669) 21.297397337 42.2986072669
# (21.2868518816, 42.3519989167) 21.2868518816 42.3519989167
# (17.182703018199998, 48.184101104700005) 17.182703018199998 48.184101104700005
# (18.07574137, 48.90942020000001) 18.07574137 48.90942020000001
# (7.4603402111, 52.307634471099995) 7.4603402111 52.307634471099995
# (20.2795797194, 42.6541449243) 20.2795797194 42.6541449243
# (7.6406093971, 51.9538425634) 7.6406093971 51.9538425634
# (21.2419446841, 48.8022438659) 21.2419446841 48.8022438659
# (20.04320862, 49.06450822) 20.04320862 49.06450822
# (20.287589198499997, 42.6559770345) 20.287589198499997 42.6559770345
# (20.2797825926, 42.6568683359) 20.2797825926 42.6568683359
# (36.7710268312, 55.67268766) 36.7710268312 55.67268766
# (16.47640361, 49.75467203) 16.47640361 49.75467203
# (21.2653419621, 42.2256082297) 21.2653419621 42.2256082297
# (21.435351721700002, 42.321476615) 21.435351721700002 42.321476615
# (21.2506624098, 42.211184545500004) 21.2506624098 42.211184545500004
# (14.596199374300001, 50.8395832978) 14.596199374300001 50.8395832978
# (21.3908401819, 42.2970780496) 21.3908401819 42.2970780496
# (18.1380926259, 48.2470418746) 18.1380926259 48.2470418746
# (31.2115705479, 58.5198585643) 31.2115705479 58.5198585643
# (37.8364404928, 55.9095047371) 37.8364404928 55.9095047371

# %% [markdown]
# ##### Try to Fix Europe (not working)

# %%
eur0 = pd.read_csv('Data/europe_0.csv', error_bad_lines=False, sep=';')
print(eur0.dtypes)

eur1 = pd.read_csv('Data/europe_1.csv', error_bad_lines=False, sep=';')
print(eur1.dtypes)

eur8 = pd.read_csv('Data/europe_8.csv', error_bad_lines=False, sep=';')
print(eur8.dtypes)
# Out:
# id                 int64
# latitude         float64
# longitude        float64
# continent         object
# country           object
# aa1               object
# aa2               object
# aa3               object
# locality          object
# subLocality       object
# types             object
# updateTime        object
# updateNeeded        bool
# note              object
# url               object
# status            object
# size              object
# anonymous           bool
# created           object
# accessibility     object
# image             object
# dtype: object
# id                         object
# latitude                   object
# longitude                  object
# continent                  object
# country                    object
# aa1                        object
# aa2                        object
# aa3                        object
# locality                   object
# subLocality                object
# types                      object
# updateTime                 object
# updateNeeded               object
# note                       object
# url                       float64
# status                    float64
# size                      float64
# anonymous                 float64
# created                   float64
# accessibility             float64
# image,,,,,,,,,,,,,,,,,    float64
# dtype: object
# id               object
# latitude         object
# longitude        object
# continent        object
# country          object
# aa1              object
# aa2              object
# aa3              object
# locality         object
# subLocality      object
# types            object
# updateTime       object
# updateNeeded     object
# note             object
# url              object
# status           object
# size             object
# anonymous        object
# created          object
# accessibility    object
# image            object
# dtype: object

# %%
import numpy as np

a = np.array(eur1['latitude'].values)
b = [float(elem) for elem in a]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-148-c6cf10b64f55> in <module>()
#       2
#       3 a = np.array(eur1['latitude'].values)
# ----> 4 b = [float(elem) for elem in a]
#
# <ipython-input-148-c6cf10b64f55> in <listcomp>(.0)
#       2
#       3 a = np.array(eur1['latitude'].values)
# ----> 4 b = [float(elem) for elem in a]
#
# ValueError: could not convert string to float: '2019-06-03T17:45:41.835Z""'

# %%
eur1[eur1['latitude']=='2019-06-03T17:45:41.835Z""']
# Out:
#                                                   id  ... image,,,,,,,,,,,,,,,,,
# 1  47090;"48.1648299";"17.1628742";"Europe";"Slov...  ...                    NaN
#
# [1 rows x 21 columns]

# %%
a = np.array(eur8['latitude'].values)
b = [float(elem) for elem in a]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-150-f8ac826c683f> in <module>()
#       1 a = np.array(eur8['latitude'].values)
# ----> 2 b = [float(elem) for elem in a]
#
# <ipython-input-150-f8ac826c683f> in <listcomp>(.0)
#       1 a = np.array(eur8['latitude'].values)
# ----> 2 b = [float(elem) for elem in a]
#
# ValueError: could not convert string to float: 'stillHere'

# %%
eur8[eur8['latitude']=='stillHere']
# Out:
#                                                      id  ... image
# 2072  ;https://admin.trashout.ngo/trash-management/d...  ...   NaN
#
# [1 rows x 21 columns]

# %% [markdown]
# #### World Database

# %%
frames = [europe_combined, africa_combined, asia_combined, oceania_combined, 
          australia_combined, samerica_combined, namerica_combined]


world_combined = pd.concat(frames)
print(world_combined.shape)

world_db = world_combined
# Out:
# (48562, 21)

# %% [markdown]
# ### Useful Statistics

# %%
# List of Features
world_combined.columns
# Out:
# Index(['id', 'latitude', 'longitude', 'continent', 'country', 'aa1', 'aa2',
#        'aa3', 'locality', 'subLocality', 'types', 'updateTime', 'updateNeeded',
#        'note', 'url', 'status', 'size', 'anonymous', 'created',
#        'accessibility', 'image'],
#       dtype='object')

# %%
#Missing percentage of column accessibility
missing = world_combined[world_combined['accessibility'].isnull()]
missing_perc = len(missing) / len(world_combined) * 100
print('Missing Total: {}\nMissing Percentage of column accessibility: {:.2f}%'.format(len(missing), missing_perc))

#Missing percentage of column aa3
missing = world_combined[world_combined['aa3'].isnull()]
missing_perc = len(missing) / len(world_combined) * 100
print('Missing Total: {}\nMissing Percentage of column aa3: {:.2f}%'.format(len(missing), missing_perc))
# Out:
# Missing Total: 41191
# Missing Percentage of column accessibility: 84.82%
# Missing Total: 43756
# Missing Percentage of column aa3: 90.10%

# %%
print(world_combined.shape)
#dropping duplicate rows
world_combined = world_combined.drop_duplicates(subset=world_combined.columns,keep='first')
print(world_combined.shape)
world_combined.head()
# Out:
# (48562, 21)
# (48562, 21)
#       id  ...                                              image
# 0  57838  ...  https://firebasestorage.googleapis.com/v0/b/tr...
# 1  57837  ...  https://firebasestorage.googleapis.com/v0/b/tr...
# 2  57836  ...  https://firebasestorage.googleapis.com/v0/b/tr...
# 3  57831  ...  https://firebasestorage.googleapis.com/v0/b/tr...
# 4  57830  ...  https://firebasestorage.googleapis.com/v0/b/tr...
#
# [5 rows x 21 columns]

# %%
#scatterplot to visualize our geospatial data
import matplotlib.pyplot as plt
import seaborn as sns
plt.figure(figsize = (15,10))
sns.scatterplot(world_combined['longitude'], world_combined['latitude'])

# %%
# Info on Features
world_combined.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 48562 entries, 0 to 4999
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   id             48562 non-null  int64
#  1   latitude       48562 non-null  float64
#  2   longitude      48562 non-null  float64
#  3   continent      48513 non-null  object
#  4   country        48513 non-null  object
#  5   aa1            44595 non-null  object
#  6   aa2            38860 non-null  object
#  7   aa3            4806 non-null   object
#  8   locality       38807 non-null  object
#  9   subLocality    15898 non-null  object
#  10  types          48554 non-null  object
#  11  updateTime     48562 non-null  object
#  12  updateNeeded   48562 non-null  bool
#  13  note           12012 non-null  object
#  14  url            48562 non-null  object
#  15  status         48562 non-null  object
#  16  size           48562 non-null  object
#  17  anonymous      48562 non-null  bool
#  18  created        48562 non-null  object
#  19  accessibility  7371 non-null   object
#  20  image          48414 non-null  object
# dtypes: bool(2), float64(2), int64(1), object(16)
# memory usage: 7.5+ MB

# %%
# Continents statistics by Continent
world_combined['continent'].value_counts()
# Out:
# Europe           34955
# North America     6353
# Africa            5324
# Asia              1512
# South America      271
# Australia           87
# Oceania             11
# Name: continent, dtype: int64

# %%
# Overview of unique values in a field
set(world_combined['types'])
# Out:
# {nan,
#  'construction,glass,electronic,domestic,metal,plastic',
#  'domestic,dangerous,electronic',
#  'construction,plastic,glass,metal,domestic',
#  'glass,metal,domestic,dangerous,liquid,plastic',
#  'glass,metal,deadAnimals,liquid,plastic,domestic',
#  'dangerous,glass,electronic,plastic',
#  'automotive,metal,plastic,glass,electronic,construction,dangerous',
#  'liquid,glass,metal,organic,plastic,construction,domestic',
#  'plastic,automotive,dangerous,liquid,metal,electronic,construction,glass,domestic',
#  'metal,glass,electronic,domestic,construction,plastic',
#  'domestic,metal,glass,plastic,construction',
#  'glass,construction,electronic',
#  'automotive,liquid,metal',
#  'automotive,construction,plastic,domestic',
#  'automotive,construction',
#  'automotive,dangerous,metal,plastic,liquid,glass,electronic,domestic,construction',
#  'liquid,glass,deadAnimals,metal,plastic',
#  'metal,glass,domestic,construction,plastic',
#  'deadAnimals,dangerous,organic,plastic,domestic',
#  'construction,domestic,metal,plastic',
#  'glass,plastic,construction,automotive,domestic',
#  'metal,glass,domestic,automotive,plastic,liquid',
#  'plastic,construction,domestic',
#  'glass,plastic,dangerous',
#  'glass,construction,domestic,automotive,metal,plastic',
#  'glass,construction,electronic,metal,dangerous,automotive,plastic',
#  'glass,metal,construction,plastic,electronic',
#  'metal,glass,liquid,plastic,domestic',
#  'liquid,metal,organic,electronic,plastic,construction,automotive,domestic',
#  'electronic,domestic,construction,dangerous',
#  'construction,plastic,dangerous,domestic,metal,liquid,glass',
#  'deadAnimals,organic,metal,glass,liquid,plastic',
#  'construction,glass,domestic,metal,automotive,plastic,electronic',
#  'automotive,metal,domestic,construction,plastic,glass',
#  'glass,automotive,electronic,domestic,plastic,construction,dangerous',
#  'glass,deadAnimals,liquid,metal,electronic,plastic,domestic',
#  'plastic,construction,liquid',
#  'metal,electronic,construction,domestic',
#  'plastic,construction,glass,metal,automotive,domestic',
#  'construction,glass,domestic,automotive,plastic',
#  'domestic,glass,construction,automotive,plastic',
#  'dangerous,organic,plastic',
#  'automotive,metal,domestic,glass,plastic',
#  'domestic,construction,automotive,electronic',
#  'construction,domestic,automotive,plastic',
#  'glass,metal,plastic,electronic,domestic',
#  'liquid,metal,glass,electronic,plastic,domestic,dangerous,automotive,construction',
#  'metal,glass,automotive,plastic,domestic,construction',
#  'metal,dangerous,domestic',
#  'metal,liquid,plastic',
#  'metal,domestic,plastic,automotive,electronic,glass',
#  'glass,metal,plastic,organic',
#  'deadAnimals,domestic',
#  'domestic,construction',
#  'construction,plastic,glass,electronic,domestic,metal',
#  'domestic,automotive,metal,construction,plastic',
#  'electronic,domestic,metal,plastic,construction',
#  'liquid,glass,automotive,plastic,dangerous,construction',
#  'glass,metal,liquid,plastic,electronic,dangerous,domestic,construction,automotive',
#  'construction,dangerous,metal,electronic,glass,plastic,automotive,domestic',
#  'glass,deadAnimals,metal,plastic,automotive,domestic',
#  'dangerous,organic,plastic,automotive,domestic',
#  'metal,organic,deadAnimals,electronic,plastic,construction,domestic',
#  'automotive,domestic,construction,plastic',
#  'plastic,metal,automotive,glass,domestic,construction',
#  'glass,construction,automotive,metal,plastic',
#  'glass,metal,organic,plastic,domestic',
#  'liquid,electronic,metal,automotive,dangerous,glass,plastic,domestic,construction',
#  'plastic,construction,domestic,automotive,glass',
#  'domestic,liquid,metal,construction,glass,dangerous,plastic',
#  'glass,plastic,organic',
#  'glass,metal,domestic,plastic,electronic',
#  'plastic,domestic,construction,metal,glass',
#  'construction,metal',
#  'metal,electronic,construction,domestic,plastic',
#  'glass,domestic,plastic,metal,automotive,construction,liquid,electronic',
#  'electronic,domestic,liquid,construction,metal,automotive,plastic,glass',
#  'domestic,electronic,automotive,plastic,construction',
#  'domestic,automotive,electronic,plastic,glass,metal',
#  'dangerous,metal,domestic,plastic,automotive,construction,electronic,glass',
#  'plastic,electronic,automotive,construction,metal,glass,domestic',
#  'electronic,glass,metal,plastic,domestic',
#  'metal,construction,domestic,electronic,glass,automotive,liquid,plastic',
#  'liquid,metal,domestic,electronic,plastic',
#  'glass,plastic,domestic,construction,electronic,metal',
#  'glass,metal,construction,domestic,liquid,plastic,dangerous,electronic',
#  'domestic,construction,liquid,automotive,metal,dangerous',
#  'domestic,automotive,electronic,construction,plastic,glass',
#  'plastic,glass,construction,domestic,metal',
#  'liquid,glass,deadAnimals,metal,organic,plastic,construction,domestic',
#  'glass,deadAnimals,electronic,plastic,domestic',
#  'automotive,domestic,metal,construction',
#  'organic,plastic,automotive,domestic',
#  'glass,liquid,metal,organic,plastic,electronic',
#  'dangerous,glass,deadAnimals,metal,liquid,organic,construction,electronic,plastic,domestic,automotive',
#  'plastic,liquid,dangerous,metal,domestic,electronic,glass',
#  'deadAnimals,metal,domestic',
#  'domestic,dangerous,plastic,glass,construction,liquid',
#  'glass,liquid,metal,organic,plastic,construction',
#  'organic,glass,metal,liquid,electronic,plastic',
#  'electronic,dangerous',
#  'plastic,dangerous,glass,metal',
#  'electronic,metal,domestic,plastic,construction,glass',
#  'domestic,glass,metal,liquid,plastic',
#  'deadAnimals,liquid,metal,organic,plastic,domestic',
#  'metal,glass,plastic,automotive,construction,domestic',
#  'liquid,domestic',
#  'glass,plastic,domestic,construction,automotive',
#  'domestic,construction,liquid,automotive,plastic,dangerous,metal,electronic,glass',
#  'metal,plastic,construction,automotive,domestic',
#  'automotive,metal,domestic,plastic',
#  'automotive,glass,domestic,plastic',
#  'construction,glass,liquid,dangerous,electronic,metal,domestic,automotive,plastic',
#  'plastic,domestic,construction,glass,dangerous,automotive',
#  'plastic,construction,glass,automotive,metal,liquid,electronic,domestic',
#  'liquid,metal,automotive,plastic,glass',
#  'plastic,domestic,metal,dangerous,automotive,liquid,glass,construction',
#  'automotive,plastic,metal',
#  'domestic,glass,automotive,metal,construction,plastic',
#  'dangerous,liquid,metal,organic,plastic,construction,automotive,domestic',
#  'organic,glass,deadAnimals,plastic,domestic',
#  'deadAnimals,organic,automotive',
#  'automotive,electronic,plastic,glass',
#  'metal,domestic,construction,electronic,plastic,automotive,glass',
#  'electronic,plastic,metal,domestic,glass,construction',
#  'glass,liquid,plastic,automotive,domestic',
#  'metal,glass,automotive,construction,plastic,electronic,dangerous,domestic',
#  'glass,organic,metal,plastic,domestic',
#  'plastic,automotive,liquid,metal,construction,glass,domestic',
#  'glass,construction,electronic,metal,plastic',
#  'dangerous,glass,construction,automotive,electronic,plastic,metal,domestic',
#  'domestic,construction,glass,plastic,liquid,metal,automotive,dangerous,electronic',
#  'deadAnimals,dangerous,liquid,metal,construction,automotive,domestic',
#  'metal,domestic,construction,glass',
#  'dangerous,liquid,metal,plastic',
#  'metal,plastic,construction,automotive',
#  'glass,domestic,metal,construction,liquid',
#  'construction,glass,metal,domestic,automotive',
#  'automotive,plastic,glass,domestic',
#  'glass,deadAnimals,dangerous,liquid,metal,organic,electronic,plastic,automotive,domestic',
#  'construction,metal,plastic,glass,liquid,automotive,domestic,dangerous',
#  'glass,metal,organic,plastic,electronic,construction,domestic',
#  'glass,deadAnimals,liquid,organic,domestic',
#  'metal,plastic,electronic,automotive,domestic,construction',
#  'glass,electronic,plastic,metal',
#  'domestic,electronic,construction,plastic,automotive,glass',
#  'dangerous,plastic',
#  'automotive,plastic,electronic,construction,domestic',
#  'construction,domestic,dangerous,plastic',
#  'domestic,construction,automotive,plastic,glass,electronic',
#  'electronic,liquid,metal,automotive,dangerous,construction,plastic,glass,domestic',
#  'construction,automotive,glass,electronic,metal,domestic,plastic,liquid',
#  'plastic,glass,metal',
#  'glass,deadAnimals,organic,electronic,plastic,construction,domestic',
#  'glass,construction,plastic,metal',
#  'glass,domestic,dangerous,construction,liquid,plastic,electronic,metal,automotive',
#  'glass,plastic,automotive,domestic,metal',
#  'glass,automotive,electronic,domestic,plastic,construction,dangerous,liquid,metal',
#  'glass,construction,plastic,metal,domestic',
#  'plastic,glass,domestic',
#  'glass,deadAnimals,metal,organic',
#  'metal,construction,organic,glass,plastic,domestic',
#  'plastic,automotive,domestic,glass',
#  'metal,dangerous',
#  'construction,plastic',
#  'plastic,construction,automotive,glass,domestic,electronic,metal',
#  'automotive,liquid,glass,metal,plastic',
#  'automotive,construction,domestic',
#  'domestic,glass,dangerous,construction,plastic',
#  'domestic,plastic,glass,liquid,automotive,metal,dangerous,electronic',
#  'domestic,glass,plastic,metal,construction',
#  'domestic,plastic,glass,metal,construction',
#  'metal,liquid,glass',
#  'glass,metal,electronic,plastic,domestic,automotive,construction',
#  'electronic,metal,construction,plastic,glass,domestic',
#  'deadAnimals,liquid,electronic,metal,plastic,domestic',
#  'automotive,metal,construction',
#  'electronic,construction,metal,plastic,liquid,glass,domestic,automotive',
#  'metal,electronic,plastic,construction,domestic',
#  'liquid,automotive,dangerous,plastic,glass,metal,electronic,domestic,construction',
#  'metal,glass,liquid,domestic,plastic',
#  'construction,metal,domestic',
#  'electronic,glass,plastic,metal,organic,domestic',
#  'glass,liquid,electronic,plastic,construction,automotive',
#  'domestic,glass,plastic',
#  'metal,glass,domestic,construction,plastic,electronic,liquid',
#  'automotive,dangerous,domestic,construction,electronic',
#  'dangerous,plastic,metal,glass,domestic,construction',
#  'electronic,glass,metal,domestic,construction,automotive,plastic',
#  'automotive,glass,electronic,metal',
#  'construction,glass,dangerous',
#  'glass,construction,electronic,metal,domestic,plastic',
#  'liquid,metal,glass,electronic,domestic,plastic,dangerous,automotive,construction',
#  'glass,metal,plastic,domestic,automotive',
#  'construction,metal,plastic,glass',
#  'plastic,electronic,metal,domestic',
#  'glass,construction,electronic,plastic,domestic',
#  'glass,deadAnimals,liquid,metal,organic,electronic,plastic,automotive',
#  'organic,metal,automotive,domestic,plastic',
#  'automotive,plastic,dangerous',
#  'domestic,construction,glass,plastic,automotive,metal',
#  'automotive,plastic,glass,electronic,liquid,construction',
#  'glass,dangerous,liquid,metal,plastic,construction,automotive,domestic',
#  'liquid,metal',
#  'electronic,plastic,dangerous,domestic',
#  'domestic,plastic,metal,automotive',
#  'plastic,metal,domestic,glass,construction',
#  'glass,construction,automotive,domestic,plastic',
#  'organic,construction',
#  'metal,plastic,domestic,construction',
#  'domestic,glass,metal,dangerous,construction,electronic,plastic',
#  'glass,deadAnimals,liquid,metal,organic,plastic,construction',
#  'electronic',
#  'glass,liquid,dangerous,automotive,plastic,metal,electronic,construction,domestic',
#  'electronic,plastic,metal,construction,domestic,glass,automotive',
#  'construction,metal,liquid,domestic,plastic,dangerous,glass',
#  'construction,automotive,plastic,metal',
#  'glass,deadAnimals,dangerous,liquid,metal,domestic',
#  'liquid,plastic,automotive',
#  'plastic,organic,glass',
#  'glass,liquid,domestic,plastic,metal',
#  'construction,metal,liquid,glass',
#  'plastic,electronic,construction,domestic,glass,automotive',
#  'domestic,construction,plastic,liquid,automotive,metal,dangerous,electronic',
#  'glass,domestic,electronic,construction',
#  'dangerous,metal,domestic,construction,glass,plastic',
#  'domestic,glass,electronic,metal,plastic',
#  'deadAnimals,organic,construction',
#  'liquid,plastic,dangerous,construction,domestic',
#  'metal,liquid,glass,plastic,domestic',
#  'domestic,automotive,plastic,glass',
#  'domestic,dangerous,metal,electronic,plastic,glass,construction',
#  'domestic,plastic,liquid',
#  'glass,plastic,automotive,construction',
#  'dangerous,domestic,metal,construction,glass,plastic,automotive',
#  'metal,construction,domestic,plastic',
#  'metal,automotive,construction,electronic',
#  'metal,domestic,plastic,construction,glass,electronic',
#  'plastic,construction,automotive,domestic,glass,dangerous,metal',
#  'domestic,construction,plastic,automotive',
#  'liquid,domestic,automotive,plastic,construction,glass,metal,dangerous,electronic',
#  'glass,dangerous,liquid,metal,organic,electronic,plastic,domestic',
#  'automotive,electronic,construction,domestic,plastic,glass',
#  'glass,deadAnimals,dangerous,liquid,organic,plastic',
#  'glass,metal,electronic,plastic,domestic,automotive',
#  'glass,plastic,organic,domestic,construction',
#  'construction,plastic,metal,automotive',
#  'electronic,metal,liquid,dangerous,glass,domestic,automotive,plastic',
#  'plastic,domestic,construction,glass,electronic,automotive',
#  'glass,construction,electronic,plastic',
#  'liquid,glass,metal,plastic,domestic',
#  'glass,deadAnimals,metal,plastic,automotive',
#  'electronic,glass,plastic,domestic,metal',
#  'construction,electronic,domestic,metal,plastic,glass',
#  'construction,electronic,plastic,metal',
#  'metal,automotive,glass',
#  'liquid,domestic,plastic',
#  'dangerous,organic,construction,domestic',
#  'domestic,construction,glass,liquid,metal,dangerous,electronic',
#  'glass,plastic,domestic,metal,automotive',
#  'domestic,glass,electronic,plastic,metal',
#  'plastic,glass,metal,automotive,domestic,electronic',
#  'liquid,metal,electronic,plastic,glass',
#  'automotive,construction,glass,plastic',
#  'domestic,construction,liquid,dangerous,metal,automotive,electronic,glass,plastic',
#  'glass,metal,plastic,electronic,construction,domestic,automotive',
#  'dangerous,plastic,automotive,domestic,liquid,electronic,construction,glass',
#  'glass,dangerous,metal,plastic,electronic,construction,automotive,domestic',
#  'glass,dangerous,liquid,metal,organic,construction,automotive',
#  'glass,domestic,construction,plastic,metal',
#  'metal,dangerous,automotive,construction,plastic,liquid,electronic,glass',
#  'glass,plastic,metal,dangerous,construction',
#  'construction,glass,domestic,plastic,electronic',
#  'organic,metal,plastic,glass',
#  'metal,organic,construction',
#  'glass,deadAnimals,organic,plastic,construction',
#  'glass,metal,construction,automotive,domestic,plastic,dangerous,electronic',
#  'construction,dangerous,metal,domestic,glass,liquid,electronic,plastic,automotive',
#  'plastic,metal,domestic',
#  'liquid,dangerous,metal,construction,plastic',
#  'automotive,dangerous,construction',
#  'metal,glass,plastic,construction,dangerous,domestic',
#  'domestic,automotive,metal,glass,plastic',
#  'glass,automotive,construction',
#  'dangerous,liquid,domestic,glass,plastic,metal',
#  'dangerous,domestic,construction,plastic,glass',
#  'domestic,automotive,construction,plastic,metal,glass,electronic',
#  'glass,construction,electronic,metal,liquid,automotive,domestic,plastic',
#  'liquid,automotive,dangerous,domestic,plastic',
#  'metal,automotive,dangerous,electronic,plastic,glass,liquid,construction,domestic',
#  'metal,domestic,automotive,plastic,construction,glass',
#  'liquid,domestic,construction,electronic,metal,plastic',
#  'metal,organic,plastic',
#  'glass,plastic,liquid',
#  'domestic,liquid,plastic',
#  'glass,domestic,plastic,automotive',
#  'metal,construction,electronic,plastic',
#  'domestic,construction,plastic,glass,liquid,automotive,dangerous',
#  'organic,liquid,metal,domestic,plastic',
#  'glass,electronic,organic,plastic,construction,domestic',
#  'automotive,metal,glass',
#  'glass,plastic,automotive,domestic,construction',
#  'domestic,dangerous,liquid,plastic,metal',
#  'dangerous,liquid,glass,metal,plastic,automotive,domestic,construction',
#  'glass,plastic,metal,dangerous,automotive',
#  'glass,deadAnimals,liquid,metal,organic,plastic,automotive',
#  'construction,domestic,automotive',
#  'dangerous,domestic,liquid',
#  'glass,liquid,metal,organic,plastic,construction,automotive,domestic',
#  'glass,electronic,plastic,automotive',
#  'plastic,construction,domestic,automotive',
#  'glass,automotive,domestic,plastic',
#  'construction,plastic,metal,glass,electronic,automotive,liquid,domestic',
#  'glass,electronic,metal,plastic,construction,automotive,domestic',
#  'glass,electronic,metal,automotive,construction,plastic,domestic',
#  'glass,dangerous,liquid,metal,organic,construction,domestic',
#  'glass,deadAnimals,liquid,metal,plastic,automotive,domestic',
#  'electronic,construction,glass,domestic,automotive,plastic',
#  'deadAnimals,plastic,domestic',
#  'metal,organic,plastic,construction,domestic',
#  'metal,glass,plastic,construction,domestic',
#  'construction,liquid,domestic',
#  'glass,construction,automotive,plastic,metal,domestic',
#  'liquid,metal,glass,construction,automotive,domestic,plastic',
#  'domestic,construction,glass,plastic,liquid,automotive,metal,dangerous',
#  'domestic,glass,dangerous,construction,metal',
#  'metal,plastic,glass,construction',
#  'glass,liquid,metal,plastic',
#  'plastic,liquid,glass',
#  'plastic,automotive,glass,domestic',
#  'glass,construction,plastic,domestic,dangerous',
#  'dangerous,domestic,metal,construction,glass,plastic',
#  'glass,electronic,domestic,plastic,construction',
#  'domestic,organic,deadAnimals,glass',
#  'automotive,glass,plastic,metal,construction,domestic',
#  'deadAnimals,glass,metal,plastic,domestic',
#  'automotive,metal,dangerous',
#  'domestic,glass,liquid,plastic,electronic,construction',
#  'metal,deadAnimals,plastic,automotive,domestic',
#  'glass,domestic,plastic,automotive,metal',
#  'plastic,construction,domestic,metal',
#  'domestic,glass,construction,automotive,electronic',
#  'plastic,electronic,domestic,construction,glass',
#  'construction,glass,plastic',
#  'dangerous,metal,plastic,construction,domestic',
#  'electronic,liquid,domestic,glass,plastic',
#  'metal,glass,domestic,construction,automotive,plastic,electronic,liquid',
#  'electronic,plastic,liquid,glass,domestic',
#  'domestic,liquid,plastic,automotive,metal,dangerous,construction,glass,electronic',
#  'liquid,metal,glass,plastic',
#  'domestic,plastic,glass,liquid,metal,dangerous,electronic',
#  'liquid,plastic,organic,domestic',
#  'plastic,electronic,domestic,metal,glass',
#  'domestic,liquid,plastic,metal,construction',
#  'plastic,construction,metal,glass,domestic',
#  'automotive,domestic,construction,electronic,glass',
#  'liquid,construction,domestic,glass,plastic',
#  'liquid,domestic,electronic,construction,glass,plastic,automotive,dangerous',
#  'domestic,liquid,automotive',
#  'glass,automotive,electronic,domestic,plastic,construction',
#  'glass,metal,domestic,plastic,construction',
#  'glass,liquid,organic,plastic,construction,domestic',
#  'glass,plastic,electronic,metal',
#  'deadAnimals,glass,liquid,metal,organic,plastic,domestic',
#  'automotive,construction,dangerous,glass,plastic,domestic,metal',
#  'construction,domestic,glass,plastic,metal,automotive,electronic',
#  'deadAnimals,automotive,construction,plastic,metal,glass',
#  'plastic,automotive,glass,domestic,metal,construction,electronic',
#  'plastic,domestic,dangerous',
#  'dangerous,domestic,construction,metal,glass,plastic,automotive',
#  'dangerous,construction,plastic,domestic',
#  'metal,construction,electronic,glass,dangerous,plastic,domestic',
#  'glass,deadAnimals,metal,organic,plastic,construction',
#  'metal,plastic,liquid,glass,domestic,construction',
#  'glass,construction,automotive,electronic,plastic,metal,domestic',
#  'glass,liquid,organic,electronic,plastic,construction,automotive,domestic',
#  'liquid,metal,plastic,construction,domestic',
#  'construction,plastic,metal,dangerous,domestic',
#  'electronic,metal',
#  'domestic,metal,plastic,automotive,glass,construction',
#  'glass,dangerous,metal,electronic,plastic,domestic',
#  'plastic,electronic,domestic,automotive',
#  'glass,metal,electronic,plastic',
#  'domestic,construction,metal,plastic,glass',
#  'plastic,domestic,construction,glass,metal',
#  'plastic,dangerous,construction,domestic,automotive,glass,metal',
#  'plastic,glass,liquid,automotive,metal,dangerous,electronic',
#  'construction,plastic,liquid',
#  'metal,organic,electronic,plastic,construction,domestic',
#  'plastic,domestic,construction,automotive',
#  'glass,dangerous,metal,electronic,plastic,construction,domestic',
#  'electronic,glass,metal,domestic',
#  'metal,electronic,dangerous,plastic,domestic,glass',
#  'domestic,metal,dangerous,construction',
#  'liquid,plastic,dangerous,construction,glass,metal,automotive,domestic,electronic',
#  'plastic,construction,glass,domestic,automotive,dangerous,metal,electronic',
#  'deadAnimals,metal,electronic,plastic,domestic',
#  'dangerous,plastic,glass,metal',
#  'automotive,glass,electronic,plastic,domestic',
#  'liquid,metal,dangerous,construction,glass',
#  'construction,liquid,plastic,glass,automotive',
#  'metal,automotive,liquid,plastic,domestic',
#  'glass,metal,liquid,plastic,dangerous,domestic',
#  'liquid,automotive,dangerous,domestic,construction',
#  'deadAnimals,glass,metal,organic,plastic',
#  'construction,plastic,glass,liquid,metal,automotive,dangerous,electronic',
#  'deadAnimals,plastic',
#  'liquid,domestic,glass,construction',
#  'domestic,construction,metal,glass,plastic,electronic,automotive',
#  'metal,automotive,plastic,construction,glass,domestic',
#  'plastic,electronic,domestic',
#  'automotive,plastic,glass,domestic,construction,electronic',
#  'domestic,glass,construction,automotive,metal',
#  'glass,deadAnimals,dangerous,liquid,metal,organic,plastic,domestic',
#  'metal,automotive,dangerous,plastic,glass',
#  'automotive,electronic,plastic,glass,construction,liquid,metal',
#  'construction,glass,electronic,plastic,domestic',
#  'construction,glass,metal,plastic,domestic',
#  'domestic,organic,plastic,glass',
#  'glass,construction,organic,metal,domestic,plastic',
#  'domestic,construction,metal,plastic',
#  'glass,domestic,construction',
#  'glass,automotive',
#  'glass,construction,metal,plastic,domestic',
#  'plastic,domestic,glass,automotive',
#  'liquid,electronic,metal,dangerous,automotive,plastic,domestic,construction,glass',
#  'glass,metal,construction,automotive,domestic,plastic',
#  'liquid,metal,construction,domestic',
#  'dangerous,construction,glass',
#  'domestic,construction,plastic,automotive,metal,electronic',
#  'glass,plastic,organic,metal,domestic,electronic,automotive,construction',
#  'glass,deadAnimals,dangerous,metal,organic,electronic,plastic,construction,domestic',
#  'metal,automotive,plastic,construction,domestic,electronic',
#  'construction,automotive,plastic,dangerous,metal,electronic,glass',
#  'domestic,glass,plastic,construction',
#  'domestic,metal,plastic,glass,electronic,liquid,automotive',
#  'dangerous,domestic,metal,construction,glass,electronic,plastic,automotive',
#  'domestic,electronic,liquid',
#  'construction,plastic,automotive,electronic,metal',
#  'automotive,domestic,construction,glass',
#  'glass,liquid,metal,organic,domestic',
#  'metal,glass,plastic,construction',
#  'glass,domestic,automotive,metal,dangerous,plastic',
#  'glass,deadAnimals,dangerous,liquid,organic,plastic,automotive',
#  'liquid,metal,dangerous,construction',
#  'glass,liquid,metal,electronic,plastic,construction,automotive',
#  'organic,deadAnimals,metal,plastic,domestic',
#  'construction,dangerous,plastic,electronic,metal,automotive,domestic,glass,liquid',
#  'metal,automotive,plastic,glass,domestic',
#  'metal,domestic,glass',
#  'plastic,construction,domestic,electronic',
#  'glass,domestic,liquid,plastic',
#  'construction,electronic,domestic,plastic',
#  'glass,deadAnimals,dangerous,metal,plastic,domestic',
#  'electronic,construction,domestic',
#  'construction,glass,automotive,plastic,domestic,metal',
#  'domestic,plastic,glass,metal,dangerous,electronic',
#  'glass,metal,organic,plastic,domestic,construction',
#  'metal,glass,electronic,plastic,automotive,domestic,construction',
#  'domestic,plastic,metal,glass,automotive',
#  'organic,plastic,construction,automotive,domestic',
#  'domestic,construction,metal,plastic,dangerous,glass',
#  'domestic,dangerous,glass,construction,metal,plastic,liquid,electronic',
#  'construction,automotive,plastic',
#  'liquid,plastic,construction,glass',
#  'automotive,metal,construction,electronic,domestic,plastic',
#  'glass,liquid,plastic,automotive,domestic,construction,metal',
#  'glass,construction,organic,domestic,plastic',
#  'dangerous,metal,construction,automotive',
#  'domestic,glass,metal,automotive,plastic',
#  'glass,domestic,plastic,metal,construction',
#  'automotive,glass,metal,plastic,electronic,construction,domestic',
#  'organic,metal,plastic,domestic',
#  'electronic,domestic,glass,plastic,automotive,metal',
#  'plastic,domestic,glass,metal,construction',
#  'liquid,metal,glass,electronic',
#  'metal,plastic,construction,glass,domestic,electronic',
#  'metal,plastic,domestic,liquid,construction,glass,dangerous',
#  'automotive,electronic,liquid',
#  'dangerous,automotive,domestic,plastic,construction,glass,metal,electronic,liquid',
#  'metal,construction,dangerous,automotive,electronic',
#  'glass,construction,electronic,domestic,plastic',
#  'glass,plastic,electronic,domestic',
#  'automotive,electronic,metal,plastic',
#  'plastic,construction,glass,automotive,domestic,metal',
#  'electronic,construction,domestic,dangerous,automotive',
#  'plastic,construction,domestic,electronic,automotive',
#  'automotive,construction,plastic,dangerous,domestic,metal,glass,liquid',
#  'domestic,construction,plastic,glass,metal,electronic',
#  'domestic,metal,liquid,plastic,glass,automotive',
#  'glass,deadAnimals,metal,electronic,plastic,construction,automotive,domestic',
#  'glass,construction,metal,electronic,plastic,domestic',
#  'deadAnimals,dangerous,liquid,organic,plastic',
#  'automotive,domestic,metal,glass,dangerous,liquid,electronic,construction,plastic',
#  'liquid,metal,organic,electronic,plastic,construction,domestic',
#  'metal,plastic,domestic,dangerous,glass,construction',
#  'metal,dangerous,electronic,liquid,glass,automotive,plastic,domestic,construction',
#  'glass,dangerous,plastic,domestic',
#  'glass,automotive,domestic,plastic,metal,construction',
#  'domestic,liquid,plastic,metal,construction,glass,electronic',
#  'glass,electronic,dangerous',
#  'liquid,plastic,domestic,glass,construction',
#  'deadAnimals,dangerous,liquid,metal,organic,electronic,plastic,construction,domestic',
#  'plastic,construction,electronic,domestic,automotive',
#  'domestic,liquid,metal,glass,construction,dangerous,plastic',
#  'glass,organic,plastic,automotive',
#  'construction,domestic,plastic,electronic',
#  'plastic,electronic,construction,glass,metal,domestic',
#  'glass,deadAnimals,organic,electronic,plastic,construction,automotive,domestic',
#  'electronic,domestic,plastic,metal,automotive',
#  'glass,electronic,domestic,metal,plastic',
#  'glass,deadAnimals,liquid,metal,organic,automotive,domestic',
#  'domestic,dangerous,plastic',
#  'construction,plastic,automotive,liquid,glass,electronic,metal,domestic',
#  'liquid,metal,organic,plastic,domestic',
#  'deadAnimals,glass,metal,organic,plastic,automotive,domestic',
#  'electronic,plastic,glass,domestic',
#  'glass,domestic,liquid,electronic,automotive,metal',
#  'plastic,deadAnimals,glass,organic',
#  'construction,automotive,liquid,domestic,plastic',
#  'dangerous,plastic,construction,domestic',
#  'glass,metal,organic,electronic,plastic,automotive,domestic',
#  'plastic,dangerous',
#  'construction,electronic,automotive,plastic,glass,domestic,metal',
#  'liquid,plastic,construction',
#  'domestic,glass,automotive,electronic,plastic',
#  'liquid,dangerous,plastic,metal,domestic',
#  'automotive,metal,construction,domestic,glass,plastic,liquid,electronic',
#  'construction,metal,plastic,domestic,glass',
#  'domestic,glass,metal,dangerous,plastic,automotive,electronic,liquid,construction',
#  'domestic,metal,glass,construction,plastic',
#  'glass,deadAnimals,liquid,metal,plastic,construction,automotive,domestic',
#  'glass,deadAnimals,liquid,plastic,domestic',
#  'glass,domestic,metal,plastic,automotive,construction,electronic,dangerous,liquid',
#  'plastic,metal,electronic',
#  'liquid,metal,glass,electronic,automotive,dangerous,construction',
#  'glass,metal,organic,electronic,plastic,construction,domestic,dangerous',
#  'glass,construction,organic,electronic,metal,domestic,plastic',
#  'dangerous,liquid,organic,plastic',
#  'glass,metal,plastic,domestic,liquid',
#  'dangerous,metal,automotive,electronic,plastic,domestic,glass,liquid',
#  'glass,domestic,construction,plastic,electronic,automotive',
#  'construction,plastic,metal',
#  'domestic,deadAnimals,metal,glass,plastic,organic',
#  'construction,domestic,electronic,plastic,glass',
#  'glass,dangerous,liquid,metal,electronic,plastic,construction,domestic',
#  'domestic,construction,automotive,plastic,metal,electronic,glass',
#  'liquid,metal,dangerous,plastic,domestic,construction',
#  'construction,organic,electronic,metal,automotive,domestic,plastic',
#  'deadAnimals,glass,dangerous,metal,liquid,organic,electronic,plastic,construction,automotive,domestic',
#  'construction,plastic,dangerous',
#  'electronic,construction,domestic,plastic',
#  'deadAnimals,glass,metal,liquid,dangerous,plastic,electronic,organic,domestic,automotive,construction',
#  'electronic,plastic,domestic,construction,automotive,metal,liquid',
#  'metal,domestic,automotive,construction',
#  'electronic,dangerous,glass,automotive,metal,construction,domestic,plastic,liquid',
#  'glass,construction,metal,automotive,domestic,plastic',
#  'glass,metal,organic,plastic,automotive,domestic',
#  'plastic,dangerous,metal,domestic,electronic,automotive,glass,construction',
#  'construction,metal,domestic,glass',
#  'glass,liquid,metal,organic,plastic,automotive,domestic',
#  'liquid,glass,metal,organic,plastic,construction,automotive,domestic',
#  'domestic,dangerous,metal,plastic,glass',
#  'metal,dangerous,plastic,glass',
#  'construction,metal,plastic',
#  'plastic,electronic,construction,domestic,metal,dangerous',
#  'domestic,electronic,glass,plastic,automotive,metal,construction',
#  'construction,dangerous,liquid',
#  'plastic,electronic,glass,domestic,automotive',
#  'metal,construction,domestic,plastic,glass',
#  'plastic,construction,electronic,metal,glass,automotive,domestic',
#  'glass,domestic,plastic,metal',
#  'glass,construction,plastic,domestic,electronic,metal',
#  'glass,deadAnimals,metal,dangerous,plastic,electronic,domestic',
#  'organic,plastic,glass',
#  'metal,dangerous,plastic,domestic,automotive',
#  'electronic,metal,automotive,glass,plastic,domestic,construction',
#  'metal,organic,electronic,plastic',
#  'glass,liquid,metal,organic,plastic,domestic',
#  'electronic,plastic,metal',
#  'electronic,plastic,automotive,domestic',
#  'deadAnimals,automotive,domestic',
#  'plastic,domestic,automotive,metal',
#  'construction,dangerous,plastic',
#  'domestic,plastic,glass,liquid,automotive,metal,dangerous',
#  'glass,liquid,metal,organic,electronic,plastic,construction,automotive,domestic',
#  'plastic,metal,dangerous,domestic',
#  'metal,organic,plastic,construction,automotive,domestic',
#  'electronic,domestic,metal,plastic,glass',
#  'construction,plastic,automotive,metal,dangerous,glass,domestic,liquid,electronic',
#  'automotive,construction,electronic,domestic,plastic,metal',
#  'automotive,metal,construction,domestic,plastic,glass,liquid,electronic,dangerous',
#  'glass,plastic,electronic,metal,automotive,domestic,construction',
#  'glass,deadAnimals,liquid,metal,organic,electronic,plastic',
#  'glass,organic,plastic,construction,automotive,domestic',
#  'glass,metal,plastic,automotive',
#  'electronic,glass,automotive,plastic,construction,metal,domestic',
#  'liquid,dangerous,plastic',
#  'dangerous,construction,electronic,glass,metal,plastic,domestic',
#  'liquid,automotive,plastic,domestic',
#  'automotive,domestic,metal,glass,plastic',
#  'electronic,automotive,metal,construction',
#  'automotive,plastic,domestic',
#  'construction,domestic,automotive,electronic,glass',
#  'construction,electronic,dangerous,domestic',
#  'domestic,electronic,glass,automotive,plastic,metal,construction',
#  'domestic,construction,glass,plastic,liquid,automotive,metal,electronic',
#  'glass,plastic,automotive,metal,construction',
#  'glass,deadAnimals,liquid,organic,plastic,construction,automotive,domestic',
#  'construction,plastic,glass,automotive',
#  'construction,dangerous,metal,plastic,electronic',
#  'dangerous,automotive,liquid',
#  'glass,automotive,electronic,plastic,domestic',
#  'dangerous,domestic,metal,construction',
#  'automotive,plastic,domestic,metal,construction',
#  'liquid,dangerous,plastic,metal,glass,automotive',
#  'glass,domestic,metal,construction,automotive,electronic,liquid,plastic,dangerous',
#  'metal,domestic,plastic,automotive,construction,glass,liquid,electronic',
#  'electronic,metal,automotive,plastic',
#  'metal,glass,dangerous,plastic',
#  'construction,domestic,plastic,glass,metal,electronic',
#  'automotive,electronic,domestic',
#  'automotive,plastic,construction',
#  'plastic,domestic,electronic',
#  'construction,domestic,plastic,glass,liquid,automotive,electronic',
#  'metal,glass,organic',
#  'dangerous,domestic',
#  'metal,dangerous,domestic,electronic',
#  'glass,organic,domestic,plastic',
#  'glass,organic,plastic,domestic',
#  'automotive,construction,domestic,electronic,plastic',
#  'construction,glass,electronic,domestic,plastic,metal,automotive',
#  'construction,plastic,glass,automotive,metal,dangerous',
#  'glass,deadAnimals,liquid,electronic,plastic,domestic',
#  'glass,automotive,liquid,plastic,metal',
#  'plastic,automotive,construction,domestic',
#  'dangerous,metal,electronic,plastic,construction,automotive,domestic',
#  'plastic,deadAnimals,organic',
#  'plastic,organic,construction,domestic',
#  'electronic,automotive,plastic,domestic',
#  'deadAnimals,glass,construction,liquid,metal,electronic,plastic,domestic',
#  'automotive,plastic,domestic,construction,glass,metal,liquid',
#  'plastic,metal,automotive',
#  'metal,glass,plastic,construction,automotive,domestic',
#  'domestic,construction,plastic,electronic',
#  'glass,liquid,metal,organic,electronic,plastic,automotive',
#  'glass,dangerous,metal,construction,organic,plastic,electronic,domestic',
#  'domestic,electronic,metal,construction,glass,plastic,automotive',
#  'dangerous,domestic,automotive',
#  'construction,metal,domestic,dangerous,plastic',
#  'dangerous,automotive,electronic,plastic,glass,construction,metal',
#  'glass,deadAnimals,dangerous,liquid,metal,organic,electronic,plastic,construction,automotive',
#  'glass,liquid,metal,electronic,domestic',
#  'glass,dangerous,liquid,organic,plastic,domestic',
#  'metal,construction,dangerous,glass,domestic,liquid,automotive,electronic,plastic',
#  'domestic,metal,plastic,dangerous,electronic,glass',
#  'construction,glass,metal,electronic,plastic',
#  'dangerous,glass,metal,plastic,domestic',
#  'liquid,glass,deadAnimals,metal,electronic,plastic,domestic',
#  'liquid,plastic,dangerous,domestic,metal,electronic,glass,automotive,construction',
#  'construction,electronic,automotive,glass,domestic,plastic,metal',
#  'dangerous,plastic,electronic',
#  'glass,construction,metal,domestic,liquid,plastic,electronic,automotive',
#  'glass,dangerous,metal,domestic,liquid,plastic,electronic,construction,automotive',
#  'dangerous,domestic,automotive,electronic,plastic,glass,construction,metal',
#  'glass,dangerous,metal,electronic,plastic,construction,automotive',
#  'liquid,metal,plastic,domestic',
#  'glass,domestic,automotive,plastic',
#  'liquid,dangerous,glass,construction,electronic,metal,automotive,domestic,plastic',
#  'plastic,electronic,construction,domestic,metal,glass,automotive',
#  'organic,electronic,plastic,construction,automotive,domestic',
#  'domestic,construction,glass,plastic,metal,dangerous,electronic',
#  'plastic,construction,glass,automotive,domestic',
#  'domestic,construction,metal,glass,plastic',
#  'dangerous,domestic,electronic,plastic,glass,construction,metal',
#  'construction,domestic,plastic,glass,metal,dangerous',
#  'domestic,plastic,construction,metal',
#  'construction,metal,domestic,automotive,plastic,glass',
#  'glass,organic,electronic,plastic,domestic',
#  'metal,construction,glass,plastic,electronic,dangerous,domestic',
#  'glass,domestic,construction,metal,plastic,liquid',
#  'metal,plastic,domestic,electronic,liquid,glass,dangerous,construction,automotive',
#  'glass,metal,liquid,electronic,plastic,dangerous,domestic,construction,automotive',
#  'glass,plastic,organic,metal,domestic,automotive,construction,dangerous',
#  'construction,plastic,automotive,domestic',
#  'domestic,plastic,metal,construction,automotive',
#  'dangerous,domestic,plastic,glass',
#  'glass,construction,automotive,domestic,plastic,dangerous,electronic',
#  'construction,metal,domestic,plastic',
#  'glass,metal,electronic,construction,plastic',
#  'domestic,electronic,metal,plastic,automotive,glass',
#  'domestic,construction,electronic',
#  'liquid,dangerous,domestic,construction,plastic',
#  'dangerous,domestic,metal,construction,electronic,plastic,automotive,liquid',
#  'construction,plastic,domestic,metal,automotive,glass',
#  'plastic,glass,domestic,electronic,automotive',
#  'construction,metal,plastic,domestic',
#  'glass,construction,automotive,plastic,metal',
#  'construction,plastic,liquid,automotive,metal,domestic',
#  'glass,dangerous,construction,plastic,metal,domestic',
#  'domestic,glass,plastic,electronic,metal',
#  'construction,domestic,electronic,plastic,glass,metal',
#  'domestic,metal,construction,plastic',
#  'construction,domestic,plastic,glass,automotive,metal',
#  'construction,electronic,plastic,domestic,dangerous,automotive,glass',
#  'domestic,automotive,electronic',
#  'deadAnimals,glass,liquid,metal,domestic,plastic,organic',
#  'construction,domestic,dangerous,automotive',
#  'metal,glass,construction',
#  'liquid,metal,dangerous,domestic,plastic',
#  'metal,liquid,dangerous',
#  'domestic,plastic,automotive,metal',
#  'glass,dangerous,liquid,automotive,electronic',
#  'glass,plastic,domestic,automotive,electronic,metal',
#  'glass,dangerous,liquid,electronic,plastic,construction,automotive,domestic',
#  'domestic,construction,glass,metal,electronic',
#  'glass,dangerous,metal,construction,plastic',
#  'automotive,glass,construction,plastic,domestic,dangerous,electronic',
#  'automotive,dangerous,liquid,electronic',
#  'electronic,domestic,metal,glass,construction,automotive,plastic',
#  'glass,deadAnimals,dangerous,liquid,metal,organic,electronic,plastic,construction,domestic',
#  'liquid,electronic,plastic,domestic,construction,metal,glass',
#  'metal,glass,organic,plastic,domestic',
#  'plastic,construction,glass,domestic,liquid',
#  'construction,electronic,metal,domestic,plastic',
#  'glass,metal,organic,electronic,plastic,construction,domestic',
#  'glass,deadAnimals,organic,electronic,plastic,construction',
#  'construction,domestic,glass',
#  'dangerous,electronic,construction',
#  'dangerous,automotive,plastic',
#  'domestic,dangerous,automotive,electronic,plastic,glass,construction',
#  'glass,deadAnimals,liquid,organic,plastic,domestic',
#  'liquid,automotive,domestic,plastic,glass',
#  'plastic,construction,automotive,domestic,glass,metal',
#  'automotive,glass,domestic,construction,metal,plastic,electronic',
#  'domestic,organic,construction',
#  'domestic,plastic,construction,electronic,glass,automotive,metal',
#  'plastic,metal',
#  'electronic,glass,deadAnimals,metal,plastic,domestic',
#  'electronic,glass,domestic',
#  'dangerous,construction,domestic,glass',
#  'plastic,electronic,construction',
#  'metal,electronic,liquid,glass,plastic,domestic,dangerous,construction,automotive',
#  'dangerous,plastic,glass',
#  'glass,construction,automotive,plastic,electronic',
#  'metal,plastic,domestic,automotive',
#  'domestic,construction,glass,plastic,metal',
#  'automotive,plastic,glass,domestic,electronic,metal',
#  'metal,glass,domestic,plastic,construction',
#  'plastic,construction,automotive,metal,glass',
#  'automotive,metal,plastic,glass,construction',
#  'domestic,glass,automotive,plastic',
#  'liquid,plastic,metal,dangerous,electronic',
#  'domestic,plastic,electronic,construction,metal,glass,automotive',
#  'automotive,electronic,plastic',
#  'glass,electronic,metal,plastic,domestic,construction',
#  'construction,domestic,glass,plastic,automotive,dangerous',
#  'glass,dangerous,liquid,metal,plastic,automotive,domestic',
#  'automotive,plastic,electronic,glass,metal',
#  'dangerous,plastic,metal',
#  'plastic,domestic,metal,glass,automotive,construction',
#  'domestic,construction,plastic,glass,liquid,electronic',
#  'construction,electronic',
#  'plastic,electronic,construction,glass,domestic',
#  'dangerous,glass,domestic,plastic',
#  'plastic,dangerous,domestic',
#  'glass,domestic,metal',
#  'automotive,construction,electronic,glass',
#  'glass,plastic,organic,metal,domestic,deadAnimals',
#  'domestic,electronic',
#  'domestic,plastic,electronic,automotive,metal',
#  'metal,glass,domestic,plastic,electronic,construction,automotive',
#  'glass,metal,plastic,construction',
#  'glass,plastic,metal,domestic,construction',
#  'glass,electronic,metal,plastic,automotive,domestic',
#  'glass,deadAnimals,liquid,metal,organic,construction,domestic',
#  'domestic,glass,plastic,liquid,metal,dangerous,electronic',
#  'deadAnimals,glass,organic,domestic',
#  'automotive,construction,glass,electronic,plastic',
#  'construction,organic,electronic,automotive,domestic,plastic',
#  'domestic,dangerous,automotive,glass,construction,metal',
#  'domestic,construction,electronic,plastic,glass',
#  'liquid,glass,domestic,plastic,metal,construction',
#  'construction,plastic,automotive,domestic,glass,metal',
#  'glass,deadAnimals,plastic,organic,domestic',
#  'metal,construction,plastic,dangerous,domestic',
#  'glass,automotive,plastic,metal,domestic',
#  'domestic,glass,plastic,electronic,construction',
#  'construction,domestic,plastic,glass,liquid,automotive,metal,dangerous,electronic',
#  'construction,dangerous,metal,electronic,plastic,glass,automotive,domestic',
#  'domestic,metal,organic',
#  'plastic,metal,electronic,domestic',
#  'glass,dangerous,plastic,electronic',
#  'domestic,glass,construction,liquid,plastic',
#  'metal,construction,glass,plastic,domestic',
#  'deadAnimals,glass,liquid,organic',
#  'plastic,dangerous,metal,glass,electronic,construction,automotive,domestic,liquid',
#  'electronic,construction,plastic',
#  'domestic,plastic,glass',
#  'dangerous,glass,metal,plastic',
#  'glass,dangerous,liquid,plastic,construction,domestic',
#  'plastic,electronic,domestic,glass,construction',
#  'domestic,metal,automotive',
#  'glass,deadAnimals,liquid,electronic,metal,plastic,domestic',
#  'glass,deadAnimals,liquid,metal,organic,plastic,domestic',
#  'glass,deadAnimals,dangerous,organic,electronic,plastic,construction,automotive,domestic',
#  'domestic,metal,plastic,glass,automotive',
#  'plastic,domestic,glass,metal,automotive',
#  'metal,construction',
#  'organic,liquid,glass,deadAnimals,metal,plastic,domestic',
#  'liquid,automotive,dangerous,metal',
#  'metal,domestic,dangerous,automotive,construction,plastic',
#  'glass,organic,domestic,construction,automotive,plastic',
#  'glass,dangerous,liquid,electronic,organic,metal,plastic,construction,automotive,domestic',
#  'construction,automotive,glass,liquid,domestic,plastic,electronic,dangerous,metal',
#  'plastic,electronic,liquid,automotive,construction,metal,glass,domestic',
#  'construction,glass,electronic,automotive',
#  'plastic,metal,glass,liquid,construction,domestic',
#  'automotive,plastic,domestic,electronic,construction,dangerous',
#  'glass,automotive,plastic,domestic',
#  'plastic,automotive,electronic,domestic',
#  'glass,electronic,plastic,construction,automotive',
#  'domestic,construction,dangerous',
#  'liquid,dangerous,glass,deadAnimals,metal,organic,electronic,plastic,construction,automotive,domestic',
#  'liquid,electronic,metal,dangerous,automotive,construction,glass,domestic,plastic',
#  'metal,automotive,dangerous',
#  'metal,automotive,domestic,construction,electronic',
#  'construction,domestic,electronic',
#  'liquid,domestic,plastic,glass',
#  'electronic,metal,automotive,domestic,plastic',
#  'electronic,metal,liquid,dangerous,glass,domestic,plastic',
#  'liquid,glass,automotive,plastic,metal',
#  'plastic,organic',
#  'construction,plastic,domestic,metal,glass',
#  'glass,automotive,metal,plastic',
#  'plastic,automotive,liquid,glass,electronic',
#  'electronic,liquid,plastic,metal,construction,dangerous,glass,automotive,domestic',
#  'automotive,dangerous,domestic,construction,plastic,liquid,glass,metal,electronic',
#  'plastic,domestic,construction,glass,metal,electronic,liquid',
#  'electronic,metal,plastic,glass,domestic,automotive',
#  'domestic,dangerous,construction,plastic',
#  'glass,construction,electronic,dangerous,domestic,plastic',
#  'construction,plastic,automotive,metal,dangerous,electronic',
#  'metal,organic,glass,construction,plastic',
#  'liquid,construction,automotive,electronic,glass,plastic,domestic,metal',
#  'glass,construction,plastic,automotive,electronic,domestic,metal',
#  'electronic,automotive,construction,plastic,domestic,glass',
#  'domestic,glass,plastic,construction,metal',
#  'plastic,domestic,automotive,construction,electronic',
#  'metal,glass,deadAnimals,organic,plastic,domestic',
#  'metal,automotive,dangerous,plastic,electronic,glass,liquid,construction,domestic',
#  'glass,dangerous,liquid,metal,organic,plastic,construction,domestic',
#  'automotive,plastic,domestic,glass',
#  'glass,deadAnimals,dangerous,liquid,metal,organic,electronic,plastic,automotive',
#  'domestic,automotive,glass',
#  'domestic,dangerous,liquid',
#  'glass,deadAnimals,metal,organic,plastic,construction,domestic',
#  'domestic,glass,plastic,dangerous,construction',
#  'metal,plastic,domestic,glass,liquid',
#  'glass,construction,automotive,domestic,plastic,dangerous',
#  'automotive,metal,construction,plastic,domestic',
#  'plastic,domestic,glass,electronic',
#  'domestic,metal,dangerous',
#  'construction,metal,domestic,electronic,plastic,glass',
#  'automotive,electronic,plastic,metal',
#  'glass,deadAnimals,liquid,metal,organic,electronic,automotive,domestic',
#  'plastic,construction,glass,domestic,automotive',
#  'metal,dangerous,plastic,domestic',
#  'glass,dangerous,domestic,construction,plastic,electronic,automotive,metal',
#  'construction,electronic,metal',
#  'metal,liquid,plastic,glass,domestic,construction',
#  'domestic,automotive,plastic,metal,glass',
#  'domestic,dangerous,plastic,glass,construction,metal',
#  'plastic,domestic,construction',
#  'domestic,automotive,plastic,construction',
#  'organic',
#  'dangerous,liquid,metal,organic,electronic,plastic,automotive,domestic',
#  'metal,construction,automotive,plastic',
#  'dangerous,domestic,construction,plastic',
#  'metal,dangerous,construction,plastic,electronic,glass',
#  'construction,plastic,domestic,metal,electronic,glass',
#  'liquid,glass,metal,organic,construction,electronic,plastic,domestic',
#  'metal,automotive,plastic,domestic',
#  'construction,domestic,electronic,plastic,automotive,glass',
#  'plastic,metal,glass,domestic',
#  'plastic,domestic,metal,electronic,glass',
#  'glass,dangerous,metal,plastic,domestic',
#  'glass,dangerous,metal,organic,plastic',
#  'glass,deadAnimals,liquid,metal,plastic,domestic',
#  'metal,glass,construction,plastic,electronic,dangerous,domestic',
#  'organic,glass,liquid,plastic,domestic',
#  'dangerous,domestic,plastic,liquid',
#  'metal,construction,domestic,plastic,glass,liquid,electronic',
#  'glass,dangerous,liquid,metal,organic,electronic,plastic,automotive,domestic',
#  'domestic,construction,automotive,metal',
#  'dangerous,electronic,domestic',
#  'glass,organic,construction,domestic',
#  'plastic,liquid,glass,domestic,metal',
#  'dangerous,construction,plastic',
#  'deadAnimals,metal,electronic,plastic,construction,automotive,domestic',
#  'domestic,plastic,dangerous,automotive',
#  'plastic,glass,domestic,liquid',
#  'metal,construction,glass,domestic,plastic',
#  'metal,plastic,glass,construction,domestic',
#  'glass,dangerous,plastic,electronic,organic',
#  'domestic,construction,glass,plastic',
#  'dangerous,metal',
#  'glass,deadAnimals,liquid,metal,organic,plastic,construction,domestic',
#  'metal,domestic,construction,electronic,plastic,glass',
#  'glass,plastic,metal,domestic,automotive,electronic',
#  'glass,organic,plastic',
#  'glass,plastic',
#  'glass,dangerous,metal,organic,electronic,plastic,construction,domestic',
#  'metal,domestic,plastic,automotive,construction,electronic,liquid,glass',
#  'dangerous,glass,metal,liquid,plastic,construction,automotive,domestic',
#  'glass,metal,construction,plastic,dangerous',
#  'organic,domestic,glass',
#  'glass,metal,liquid,plastic,dangerous,automotive,domestic,construction',
#  'deadAnimals,glass,organic,plastic,metal',
#  'domestic,glass,dangerous',
#  'metal,plastic,dangerous',
#  'electronic,metal,plastic,glass,domestic',
#  'glass,plastic,metal,domestic,dangerous,construction,automotive',
#  'construction,plastic,domestic,dangerous,liquid',
#  'construction,liquid,plastic',
#  'plastic,glass,dangerous,construction,domestic,electronic,automotive',
#  'domestic,construction,glass,liquid,automotive,metal,dangerous,electronic',
#  'construction,metal,automotive,plastic',
#  'domestic,organic,plastic,dangerous',
#  'glass,organic,metal,domestic,plastic',
#  'construction,domestic,plastic,glass,liquid,metal,automotive,dangerous,electronic',
#  'plastic,construction,glass,automotive,domestic,dangerous,metal,electronic',
#  'deadAnimals,glass,metal,electronic,plastic,domestic',
#  'metal,automotive,glass,construction,plastic',
#  'domestic,dangerous,plastic,glass,construction,liquid,metal',
#  'glass,deadAnimals,organic,plastic,domestic',
#  'dangerous,plastic,glass,liquid',
#  'liquid,electronic,glass,automotive,plastic,metal,construction,dangerous',
#  'domestic,liquid,plastic,metal',
#  'metal,dangerous,glass,electronic,plastic,domestic',
#  'plastic,construction,glass,metal,electronic,domestic,automotive',
#  'domestic,construction,plastic,glass,automotive,metal,electronic',
#  'glass,deadAnimals,dangerous,metal,organic,plastic',
#  'metal,glass,plastic,domestic,organic',
#  'plastic,construction,domestic,glass,dangerous,electronic',
#  'plastic,electronic,dangerous,glass,liquid',
#  'liquid,metal,organic,plastic,construction,automotive,domestic',
#  'glass,plastic,organic,metal,domestic,automotive',
#  'glass,domestic,construction,plastic,automotive,metal',
#  'metal,glass,domestic,electronic,plastic,construction',
#  'metal,plastic,organic',
#  'plastic,domestic,construction,metal,electronic',
#  'metal,construction,domestic,plastic,glass,liquid,electronic,dangerous',
#  'electronic,dangerous,plastic,automotive',
#  'construction,metal,dangerous,plastic',
#  'glass,metal,dangerous,electronic,domestic,construction',
#  'glass,plastic,automotive,metal',
#  'domestic,glass,metal,plastic,construction',
#  'metal,plastic,electronic,glass,domestic',
#  'domestic,construction,automotive,electronic,plastic,metal,glass',
#  'automotive,plastic,glass,domestic,metal',
#  'glass,plastic,domestic',
#  'electronic,construction,domestic,metal,plastic,dangerous,glass',
#  'metal,plastic,automotive,domestic,construction,glass,liquid',
#  'metal,electronic,plastic,automotive',
#  'metal,dangerous,plastic,construction,domestic',
#  'plastic,metal,construction',
#  'automotive,construction,domestic,glass,plastic',
#  'glass,plastic,domestic,liquid,construction,metal',
#  'metal,automotive,plastic',
#  'liquid,glass,dangerous',
#  'dangerous,metal,glass,plastic',
#  'glass,electronic,construction,domestic',
#  'metal,plastic,glass',
#  'automotive,glass,domestic,construction,metal,plastic',
#  'liquid,electronic,glass',
#  'construction,domestic,metal,plastic,glass,automotive',
#  'construction,dangerous,automotive,domestic',
#  'glass,metal,domestic,plastic,automotive,construction',
#  'glass,organic,metal,plastic,automotive',
#  'liquid,metal,construction,plastic',
#  'glass,metal,electronic,plastic,dangerous,liquid,automotive',
#  'liquid,deadAnimals,glass,metal,plastic,electronic,domestic',
#  'glass,deadAnimals,liquid,metal,organic,electronic,plastic,domestic',
#  'glass,organic,electronic,plastic,construction,automotive,domestic',
#  'electronic,plastic,liquid,metal,dangerous',
#  'metal,plastic,liquid,glass,electronic,domestic',
#  'dangerous,liquid,plastic',
#  'glass,dangerous,liquid,metal,electronic,plastic,construction,automotive',
#  'metal,plastic,construction,glass',
#  'domestic,organic,metal,plastic',
#  'construction,plastic,electronic,metal,automotive,domestic,glass,liquid',
#  'glass,organic,metal,liquid,plastic',
#  'metal,domestic,construction',
#  'metal,automotive',
#  'glass,metal,electronic,domestic',
#  'liquid,metal,domestic,glass,plastic',
#  'metal,glass,dangerous,plastic,domestic',
#  'liquid,domestic,construction,plastic,glass',
#  ...}

# %%
world_combined['size'].value_counts()
# Out:
# car            22052
# wheelbarrow    14721
# bag            11789
# Name: size, dtype: int64

# %%
# Select only large dumpsites (size classified as 'car')
wc_car = world_combined[world_combined['size'] == 'car']
print(wc_car.shape)
# Out:
# (22052, 21)

# %%
wc_car
# Out:
#          id  ...                                              image
# 0     57838  ...  https://firebasestorage.googleapis.com/v0/b/tr...
# 1     57837  ...  https://firebasestorage.googleapis.com/v0/b/tr...
# 2     57836  ...  https://firebasestorage.googleapis.com/v0/b/tr...
# 3     57831  ...  https://firebasestorage.googleapis.com/v0/b/tr...
# 4     57830  ...  https://firebasestorage.googleapis.com/v0/b/tr...
# ...     ...  ...                                                ...
# 4993   2933  ...  https://storage.googleapis.com/trashoutngo-dev...
# 4994   2932  ...  https://storage.googleapis.com/trashoutngo-dev...
# 4996   2930  ...  https://storage.googleapis.com/trashoutngo-dev...
# 4997   2929  ...  https://storage.googleapis.com/trashoutngo-dev...
# 4999   2927  ...  https://storage.googleapis.com/trashoutngo-dev...
#
# [22052 rows x 21 columns]

# %%
world_db = wc_car

# %%
wc_simple = world_db.drop(['aa1','aa2','aa3','updateNeeded','note','anonymous'], 1)
wc_simple.head()
# Out:
#       id  ...                                              image
# 0  57838  ...  https://firebasestorage.googleapis.com/v0/b/tr...
# 1  57837  ...  https://firebasestorage.googleapis.com/v0/b/tr...
# 2  57836  ...  https://firebasestorage.googleapis.com/v0/b/tr...
# 3  57831  ...  https://firebasestorage.googleapis.com/v0/b/tr...
# 4  57830  ...  https://firebasestorage.googleapis.com/v0/b/tr...
#
# [5 rows x 15 columns]

# %% [markdown]
# ### Maps

# %% [markdown]
# #### Static Map

# %%
from shapely.geometry import Point
import geopandas as gpd
from geopandas import GeoDataFrame

geometry = [Point(xy) for xy in zip(world_db['longitude'], world_db['latitude'])]

gdf = GeoDataFrame(world_db, geometry=geometry) 

#this is a simple map that goes with geopandas
world = gpd.read_file(gpd.datasets.get_path('naturalearth_lowres'))
gdf.plot(ax=world.plot(figsize=(15, 10)), marker='o', color='red', markersize=15);

# %% [markdown]
# #### Interactive Map

# %%
# Mapping with Folium
import folium

# %%
# Map with FastMarkerCluster
from folium.plugins import FastMarkerCluster

map = folium.Map(location=[0, 0], zoom_start=2)

callback = ('function (row) {' 
                'var circle = L.circle(new L.LatLng(row[0], row[1]), {color: "red",  radius: 10000});'
                'return circle};')

map.add_child(FastMarkerCluster(world_combined[['latitude', 'longitude']].values.tolist(), callback=callback))
map
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %%
# Mapping Markers
""" NB THIS IS SLOW/NOT EFFICIENT. ONLY WORKS WELL WITH <1000 POINTS OR SO
map = folium.Map(location=[0, 0], zoom_start=2)
for i in range(0,500): # only plot the first 500 locations
  folium.Marker([world_combined.iloc[i]['latitude'], world_combined.iloc[i]['longitude']]).add_to(map)#, popup=df_counters['Name'][point]).add_to(map)
map"""
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# #### Check out some pictures

# %%
# Function to extract the first N of images of a specific type (eg 'plastic') from the urls 
def plot_images(df,number):
    """dataframe and number of images"""
    import urllib
    from IPython.display import Image 

    # List of file names 
    names = []

    for i in range(number):
        name, header = urllib.request.urlretrieve(df['image'].iloc[i])

        names.append(name)

    # images = [cv2.imread(img) for img in names]

    for file in names:
        img=plt.imread(file)
        imgplot = plt.imshow(img)
        plt.show()

# %%
import matplotlib.pyplot as plt
wc_simple_plastic = wc_simple[wc_simple['types']=='plastic']

plot_images(wc_simple_plastic,3)

# %%
wc_simple.iloc[3]
img = wc_simple.iloc[3].image
print(img)
# Out:
# https://firebasestorage.googleapis.com/v0/b/trashoutngo-dev.appspot.com/o/temp-images%2F812afbcf-d899-44b5-9edb-537c2c73f3df?alt=media&token=8fd920ab-823d-456a-baed-0c5f901b38a4

# %% [markdown]
# # External Datasets

# %% [markdown]
# ## DEM and Slope

# %%
# Installs geemap package
import subprocess

try:
    import geemap
except ImportError:
    print('geemap package not installed. Installing ...')
    subprocess.check_call(["python", '-m', 'pip', 'install', 'geemap'])

# Checks whether this notebook is running on Google Colab
try:
    import google.colab
    import geemap.eefolium as emap
except:
    import geemap as emap

# Authenticates and initializes Earth Engine
import ee

try:
    ee.Initialize()
except Exception as e:
    ee.Authenticate()
    ee.Initialize()

# %%
Map = emap.Map(center=(40, -100), zoom=4)
Map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
# Add Earth Engine dataset
dem = ee.Image("USGS/SRTMGL1_003")

# Set visualization parameters.
vis_params = {'min': 0, 'max': 4000, 'palette': ['006633', 'E5FFCC', '662A00', 'D8D8D8', 'F5F5F5']} # palette for DEM

# Add Slope 
slope = ee.Terrain.slope(dem); #print(slope.getInfo())
slope_mask = slope.lt(30) 

vis_param_slope = {'bands': 'slope', 'min': 0, 'max': 30, 'palette': ['green', 'yellow', 'red']}

"""
# Print the elevation of Mount Everest.
xy = ee.Geometry.Point([86.9250, 27.9881])
everest = xy.getInfo()['coordinates'][1], xy.getInfo()['coordinates'][0]
elev = dem.sample(xy, 30).first().get('elevation').getInfo()
print('Mount Everest elevation (m):', elev)
Map = emap.Map(center=everest, zoom=4)
"""
# Add Earth Engine layers to Map
Map = emap.Map(center=[0,0], zoom=4)
Map.addLayer(dem, vis_params, 'SRTM DEM', True, 0.5)
Map.addLayer(slope.updateMask(slope_mask), vis_param_slope, 'SRTM Slope', True, 0.5)
Map.addLayerControl()
Map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ## Cities

# %%
import geemap.eefolium as geemap
Map_C = geemap.Map()
Map_C
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
#cities_shp = 'Data/World_Cities/World_Cities.shp'
#cities = geemap.shp_to_ee(cities_shp)

#Map_C.addLayer(cities, {}, 'World Cities')
#Map_C

# %%
cities = gpd.read_file(gpd.datasets.get_path('naturalearth_cities'))
cities_db.head()

cities.plot(marker='*', color='green', markersize=5);

# %%
gdf.plot(ax=world.plot(figsize=(15, 10)), marker='o', color='red', markersize=15);
gdf.plot(ax=cities.plot(figsize=(15, 10)), marker='*', color='green', markersize=10);
